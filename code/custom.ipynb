# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

# %matplotlib inline

# %%
from utils.data import read_pickle, load_my_network
from utils.vis import reorder_cluster_ids, vis_heatmap

# %%
out = read_pickle('../pickle/reach.p')

# %%
"""This data was generated randomly, I have no idea of what to expect in terms of the number of clusters which is the point of the project"""
# Out:
# 'This data was generated randomly, I have no idea of what to expect in terms of the number of clusters which is the point of the project'

# %%
cluster_ids, clster_params, n_clusters = reorder_cluster_ids(*out)

# %%
len(cluster_ids), len(clster_params), len(n_clusters)
# Out:
# (363, 363, 363)

# %%
burnin = 1000
sim_mat, all_best_gibbs, all_sim_mats = vis_heatmap(cluster_ids)
